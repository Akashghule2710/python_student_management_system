# %%
import mysql.connector
conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
qur1='CREATE TABLE project2(name varchar(20),mobile_no varchar(20),dept varchar(20),emailid varchar(20))'
mycur=conn.cursor()
mycur.execute(qur1)
mycur.close()
conn.close()

# %%
import mysql.connector
from tkinter import*
from tkinter import messagebox
from tkinter import ttk
Win=Tk()
Win.title('STUDENT MANAGEMENT SYSTEM')
Win.iconbitmap('studicon.ico')
Win.minsize(width=1000,height=600)
Win.configure(bg='skyblue')
n1=StringVar()
m1=StringVar()
d1=StringVar()
tt=StringVar()

def show():
    conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
    mycur=conn.cursor()
    mycur.execute("select * from project1")
    result=mycur.fetchall()
    for i in result:
        treev.insert("",'end',values=(i[0],i[1],i[2],i[3]))

    

def add():
    global n1
    global m1
    global d1
    global en1
    name=n1.get()
    mobile_no=m1.get()
    dept=d1.get()
    emailid=en1.get()
    if(name=='' or mobile_no == '' or dept == '' or emailid == ''):
        messagebox.showinfo('stu info','all field are required to fill')
    else:
        conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
        qur1="INSERT INTO project2(name,mobile_no,dept,emailid)VALUES('%s','%s','%s','%s')"%(name,mobile_no,dept,emailid)
        mycur=conn.cursor()
        mycur.execute(qur1)
        conn.commit()
        mycur.close()
        conn.close()
        messagebox.showinfo('stu info','info submitted')
        n1.set('')
        m1.set('')
        d1.set('')
        en1.set('')
        tt.set('')


def delete():
    global tt
    rs=tt.get()
    if(rs==''):
        messagebox.showinfo('stu info','all field are required to fill')
    else:
        conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
        qur1="DELETE FROM project2 where name='%s'"%(rs)
        mycur=conn.cursor()
        mycur.execute(qur1)
        conn.commit()
        mycur.close()
        conn.close()
        messagebox.showinfo('stu info','info submitted')
        tt.set('')

    
#def result():
    root=Tk()
    root.configure(bg='white')
    root.title('Result')
    root.geometry('500x400')
    def disp():
        reldata=relent.get()
        if reldata=='':
            messagebox.showinfo("student info","all fields are required to fill")
        else:
            conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
            qur1="SELECT mobno from pro1t where name='%s'"%(reldata)
            mycur=conn.cursor()
            mycur.execute(qur1)
            result=mycur.fetchone()
            new.config(text='marks='+result[0]+'%')
            
            
#             result=mycur.fetchall()
#             for i in result:
#                 new.config(text=i[1]+'%')
            relent.delete(0,'end')
    resl=Label(root,text="Enter the name of student :",height=2,font="Cooper  8 bold",fg="black",bg="white")
    resl.place(x=10,y=40)
    
    rc=StringVar()
    relent=Entry(root,bg='white',fg='black',width=30,bd=5,textvariable=rc,font=('times new roman',14))
    relent.place(x=200,y=40)
    relbtn=Button(root,text='Show Result',width=20,command=disp)
    relbtn.place(x=200,y=90)
    
    new=Label(root,text="MARKS :",height=10,width=40,font="Cooper  8 bold",fg="black",bg="skyblue")
    new.place(x=10,y=200)        
    root.mainloop()
    
    
    
def clear():
    treev.delete(*treev.get_children())
def select():
    global up
    upd=up.get()
    if(upd==''):
        messagebox.showinfo('stu info','all field are required to fill')
    else:
        conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
        qur1="SELECT * from project2 where name='%s'"%(upd)
        mycur=conn.cursor()
        mycur.execute(qur1)
        result=mycur.fetchall()
        for i in result:
            e1.insert(0,i[0])
            e2.insert(0,i[1])
            e3.insert(0,i[2])
            e4.insert(0,i[3])
        up.set('')
        
    
def update():
    global n1
    global m1
    global d1
    global en1
    name=n1.get()
    mobile_no=m1.get()
    dept=d1.get()
    emailid=en1.get()
    if(name=='' or mobile_no == '' or dept == '' or emailid == ''):
        messagebox.showinfo('stu info','all field are required to fill')
    else:
        conn=mysql.connector.connect(user='root',password='Akash@2710',host='localhost',database='data11')
        qur1="UPDATE project2 SET mobile_no='%s',dept='%s',emailid='%s'where name='%s'"%(mobile_no,dept,emailid,name)
        mycur=conn.cursor()
        mycur.execute(qur1)
        conn.commit()
        mycur.close()
        conn.close()
        messagebox.showinfo('stu info','info updated')
        n1.set('')
        m1.set('')
        d1.set('')
        en1.set('')    
   
    

en1=StringVar()
lbl1=Label(Win,text='STUDENT MANAGEMENT SYSTEM',relief='ridge',bd=5,fg='yellow',bg='green',font=('times new roman',16,'bold'))
lbl1.place(x=300,y=40)

lbl2=Label(Win,text='name',relief='ridge',width=20,bd=5,fg='yellow',bg='green',font=('times new roman',12,'bold'))
lbl2.place(x=190,y=100)
e1=Entry(Win,bd=5,fg='black',width=40,bg='white',textvariable=n1,font=('times new roman',12,'bold'))
e1.place(x=385,y=100)

lbl3=Label(Win,text='mobile_no',relief='ridge',width=20,bd=5,fg='yellow',bg='green',font=('times new roman',12,'bold'))
lbl3.place(x=190,y=140)
e2=Entry(Win,bd=5,fg='black',width=40,bg='white',textvariable=m1,font=('times new roman',12,'bold'))
e2.place(x=385,y=140)

lbl4=Label(Win,text='dept',relief='ridge',width=20,bd=5,fg='yellow',bg='green',font=('times new roman',12,'bold'))
lbl4.place(x=190,y=180)
e3=Entry(Win,bd=5,fg='black',width=40,bg='white',textvariable=d1,font=('times new roman',12,'bold'))
e3.place(x=385,y=180)

lbl5=Label(Win,text='emailid',relief='ridge',width=20,bd=5,fg='yellow',bg='green',font=('times new roman',12,'bold'))
lbl5.place(x=190,y=220)
e4=Entry(Win,bd=5,fg='black',width=40,bg='white',textvariable=en1,font=('times new roman',12,'bold'))
e4.place(x=385,y=220)

lbl6=Label(Win,text='DELETE BY NAME',relief='ridge',width=20,bd=5,fg='yellow',bg='green',font=('times new roman',12,'bold'))
lbl6.place(x=190,y=400)
e5=Entry(Win,bd=5,fg='black',width=40,bg='white',textvariable=tt,font=('times new roman',12,'bold'))
e5.place(x=385,y=400)

up=StringVar()
lbl7=Label(Win,text='UPDATE BY NAME',relief='ridge',width=20,bd=5,fg='yellow',bg='green',font=('times new roman',12,'bold'))
lbl7.place(x=200,y=540)
e6=Entry(Win,bd=5,fg='black',width=40,bg='white',textvariable=up,font=('times new roman',12,'bold'))
e6.place(x=385,y=540)

shwbtn1=Button(Win,text='SHOW',width=20,command=show)
shwbtn1.place(x=200,y=320)

addbtn1=Button(Win,text='ADD',width=20,command=add)
addbtn1.place(x=500,y=320)

exbtn1=Button(Win,text='EXIT',width=20,command=Win.destroy)
exbtn1.place(x=200,y=360)

resbtn1=Button(Win,text='RESULT',width=20,command=result)
resbtn1.place(x=500,y=360)

delbtn1=Button(Win,text='DELETE',width=20,command=delete)
delbtn1.place(x=300,y=440)

upbtn1=Button(Win,text='UPDATE',width=20,command=update)
upbtn1.place(x=300,y=580)

selbtn1=Button(Win,text='SELECT',width=20,command=select)
selbtn1.place(x=190,y=580)

#treeView
treev=ttk.Treeview(Win,selectmode='browse',height=20)
treev.place(x=900,y=100,width=450)


#scrollbar
verscrollbar=ttk.Scrollbar(Win,orient="vertical",command=treev.yview)
verscrollbar.pack(side='right',fill='x')
treev.configure(xscrollcommand=verscrollbar.set)

treev["column"]=("1","2","3","4")
treev["show"]='headings'
treev.column("1",width=90,anchor='c')
treev.column("2",width=90,anchor='se')
treev.column("3",width=90,anchor='se')
treev.column("4",width=90,anchor='se')

treev.heading("1",text="name")
treev.heading("2",text="mobile_no")
treev.heading("3",text="dept")
treev.heading("4",text="emailid")

clearbtn=Button(Win,text='Clear',width=20,command=clear)
clearbtn.place(x=1000,y=560)








Win.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c944fa05ed09> in <module>
#     196 exbtn1.place(x=200,y=360)
#     197
# --> 198 resbtn1=Button(Win,text='RESULT',width=20,command=result)
#     199 resbtn1.place(x=500,y=360)
#     200
#
# NameError: name 'result' is not defined
